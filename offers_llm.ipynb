# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
from langchain.llms import OpenAI  # LLM for offer recommendations
from langchain.prompts import PromptTemplate
from langchain_groq import ChatGroq

# %%
np.random.seed(123)

# %%
sample_size = 1000
data = {
    'Customer_ID': [f'C{i+1}' for i in range(sample_size)],
    'Monthly_Calls': np.random.normal(loc=300, scale=100, size=sample_size).astype(int),
    'Monthly_SMS': np.random.poisson(lam=30, size=sample_size),
    'Data_Usage_GB': np.random.lognormal(mean=2, sigma=0.5, size=sample_size),
    'Subscription_Type': np.random.choice(['Postpaid', 'Prepaid'], size=sample_size, p=[0.6, 0.4]),
}

data['Average_Bill'] = [np.random.normal(70,15) if sub == 'Postpaid' else np.random.normal(40,10) for sub in data['Subscription_Type'] ]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Customer_ID  Monthly_Calls  Monthly_SMS  Data_Usage_GB Subscription_Type  \
# 0            C1            443           38      16.092193           Prepaid
# 1            C2            546           27       4.297761           Prepaid
# 2            C3            341           30       7.739410           Prepaid
# 3            C4            424           25       5.754387           Prepaid
# 4            C5            295           35       5.823838          Postpaid
# ..          ...            ...          ...            ...               ...
# 995        C996             74           28       3.303418          Postpaid
# 996        C997            172           34       5.704035          Postpaid
# 997        C998            351           28       4.934610          Postpaid
# 998        C999            366           25       6.371923          Postpaid
# 999       C1000            278           24      11.604271          Postpaid
#
#      Average_Bill
# 0       37.271282
# 1       51.386492
# 2       20.332755
# 3       25.643831
# 4       92.985287
# ..            ...
# 995     65.442189
# 996     68.434246
# 997     84.885176
# 998     60.227683
# 999     79.223894
#
# [1000 rows x 6 columns]

# %%
df['Monthly_Calls'] = df['Monthly_Calls'].clip(lower=0)

# %%
df.describe().T
# Out:
#                 count        mean        std        min         25%  \
# Monthly_Calls  1000.0  297.212000  99.881467   0.000000  226.000000
# Monthly_SMS    1000.0   29.625000   5.190117  16.000000   26.000000
# Data_Usage_GB  1000.0    8.440099   4.196202   1.645651    5.458518
# Average_Bill   1000.0   59.691053  20.461590  14.168032   42.622707
#
#                       50%         75%         max
# Monthly_Calls  296.000000  364.000000  629.000000
# Monthly_SMS     29.000000   33.000000   47.000000
# Data_Usage_GB    7.639541   10.514241   39.327753
# Average_Bill    59.734930   75.619664  111.915453

# %%
df.head()
# Out:
#   Customer_ID  Monthly_Calls  Monthly_SMS  Data_Usage_GB  Subscription_Type  \
# 0          C1            443           38      16.092193                  0
# 1          C2            546           27       4.297761                  0
# 2          C3            341           30       7.739410                  0
# 3          C4            424           25       5.754387                  0
# 4          C5            295           35       5.823838                  1
#
#    Average_Bill
# 0     37.271282
# 1     51.386492
# 2     20.332755
# 3     25.643831
# 4     92.985287

# %%
df['Subscription_Type'] = df['Subscription_Type'].map({'Postpaid':1,'Prepaid':0})

# %%
scaler = MinMaxScaler()
features_scaled = scaler.fit_transform(df.drop(columns= ['Customer_ID']))

# %%
similarity_matrix = cosine_similarity(features_scaled)

# %%
similarity_df = pd.DataFrame(similarity_matrix, index=df['Customer_ID'], columns= df['Customer_ID'])

# %%
similarity_df
# Out:
# Customer_ID        C1        C2        C3        C4        C5        C6  \
# Customer_ID
# C1           1.000000  0.880988  0.977922  0.910832  0.605865  0.470122
# C2           0.880988  1.000000  0.903726  0.971601  0.616182  0.593622
# C3           0.977922  0.903726  1.000000  0.955531  0.549353  0.436533
# C4           0.910832  0.971601  0.955531  1.000000  0.532249  0.512760
# C5           0.605865  0.616182  0.549353  0.532249  1.000000  0.931885
# ...               ...       ...       ...       ...       ...       ...
# C996         0.378662  0.363199  0.319649  0.286194  0.953739  0.902289
# C997         0.538553  0.496111  0.484102  0.434786  0.982932  0.901803
# C998         0.563497  0.630824  0.523669  0.549816  0.986323  0.977257
# C999         0.548643  0.609103  0.530308  0.563505  0.952617  0.978346
# C1000        0.515477  0.552856  0.455434  0.479425  0.964802  0.982138
#
# Customer_ID        C7        C8        C9       C10  ...      C991      C992  \
# Customer_ID                                          ...
# C1           0.918236  0.639008  0.587765  0.994597  ...  0.494646  0.516999
# C2           0.995758  0.535402  0.535981  0.912832  ...  0.522932  0.572130
# C3           0.928173  0.553419  0.541393  0.966780  ...  0.414325  0.466264
# C4           0.971125  0.490299  0.502093  0.920121  ...  0.413505  0.488952
# C5           0.637399  0.958285  0.968982  0.640878  ...  0.982596  0.982085
# ...               ...       ...       ...       ...  ...       ...       ...
# C996         0.384569  0.929611  0.960158  0.405597  ...  0.961381  0.959015
# C997         0.523392  0.965357  0.986715  0.559882  ...  0.963967  0.966572
# C998         0.639351  0.933689  0.963305  0.603529  ...  0.974782  0.996276
# C999         0.613446  0.918394  0.969104  0.577437  ...  0.930708  0.980930
# C1000        0.565516  0.951898  0.965201  0.553233  ...  0.974241  0.993872
#
# Customer_ID      C993      C994      C995      C996      C997      C998  \
# Customer_ID
# C1           0.985291  0.963380  0.438707  0.378662  0.538553  0.563497
# C2           0.910379  0.950279  0.473649  0.363199  0.496111  0.630824
# C3           0.944209  0.933228  0.362502  0.319649  0.484102  0.523669
# C4           0.906206  0.921540  0.394663  0.286194  0.434786  0.549816
# C5           0.652974  0.682707  0.927279  0.953739  0.982932  0.986323
# ...               ...       ...       ...       ...       ...       ...
# C996         0.417028  0.438762  0.928197  1.000000  0.983109  0.943694
# C997         0.565751  0.581597  0.917367  0.983109  1.000000  0.962835
# C998         0.618324  0.654393  0.953108  0.943694  0.962835  1.000000
# C999         0.586658  0.611133  0.947579  0.926769  0.945150  0.983524
# C1000        0.577578  0.595668  0.990401  0.945952  0.951830  0.984440
#
# Customer_ID      C999     C1000
# Customer_ID
# C1           0.548643  0.515477
# C2           0.609103  0.552856
# C3           0.530308  0.455434
# C4           0.563505  0.479425
# C5           0.952617  0.964802
# ...               ...       ...
# C996         0.926769  0.945952
# C997         0.945150  0.951830
# C998         0.983524  0.984440
# C999         1.000000  0.977933
# C1000        0.977933  1.000000
#
# [1000 rows x 1000 columns]

# %%
similarity_df_no_self = similarity_df.apply(lambda x: x.replace(1, np.nan))

# %%
similarity_df_no_self
# Out:
# Customer_ID        C1        C2        C3        C4        C5        C6  \
# Customer_ID
# C1                NaN  0.880988  0.977922  0.910832  0.605865  0.470122
# C2           0.880988  1.000000  0.903726  0.971601  0.616182  0.593622
# C3           0.977922  0.903726       NaN  0.955531  0.549353  0.436533
# C4           0.910832  0.971601  0.955531  1.000000  0.532249  0.512760
# C5           0.605865  0.616182  0.549353  0.532249  1.000000  0.931885
# ...               ...       ...       ...       ...       ...       ...
# C996         0.378662  0.363199  0.319649  0.286194  0.953739  0.902289
# C997         0.538553  0.496111  0.484102  0.434786  0.982932  0.901803
# C998         0.563497  0.630824  0.523669  0.549816  0.986323  0.977257
# C999         0.548643  0.609103  0.530308  0.563505  0.952617  0.978346
# C1000        0.515477  0.552856  0.455434  0.479425  0.964802  0.982138
#
# Customer_ID        C7        C8        C9       C10  ...      C991      C992  \
# Customer_ID                                          ...
# C1           0.918236  0.639008  0.587765  0.994597  ...  0.494646  0.516999
# C2           0.995758  0.535402  0.535981  0.912832  ...  0.522932  0.572130
# C3           0.928173  0.553419  0.541393  0.966780  ...  0.414325  0.466264
# C4           0.971125  0.490299  0.502093  0.920121  ...  0.413505  0.488952
# C5           0.637399  0.958285  0.968982  0.640878  ...  0.982596  0.982085
# ...               ...       ...       ...       ...  ...       ...       ...
# C996         0.384569  0.929611  0.960158  0.405597  ...  0.961381  0.959015
# C997         0.523392  0.965357  0.986715  0.559882  ...  0.963967  0.966572
# C998         0.639351  0.933689  0.963305  0.603529  ...  0.974782  0.996276
# C999         0.613446  0.918394  0.969104  0.577437  ...  0.930708  0.980930
# C1000        0.565516  0.951898  0.965201  0.553233  ...  0.974241  0.993872
#
# Customer_ID      C993      C994      C995      C996      C997      C998  \
# Customer_ID
# C1           0.985291  0.963380  0.438707  0.378662  0.538553  0.563497
# C2           0.910379  0.950279  0.473649  0.363199  0.496111  0.630824
# C3           0.944209  0.933228  0.362502  0.319649  0.484102  0.523669
# C4           0.906206  0.921540  0.394663  0.286194  0.434786  0.549816
# C5           0.652974  0.682707  0.927279  0.953739  0.982932  0.986323
# ...               ...       ...       ...       ...       ...       ...
# C996         0.417028  0.438762  0.928197  1.000000  0.983109  0.943694
# C997         0.565751  0.581597  0.917367  0.983109       NaN  0.962835
# C998         0.618324  0.654393  0.953108  0.943694  0.962835  1.000000
# C999         0.586658  0.611133  0.947579  0.926769  0.945150  0.983524
# C1000        0.577578  0.595668  0.990401  0.945952  0.951830  0.984440
#
# Customer_ID      C999     C1000
# Customer_ID
# C1           0.548643  0.515477
# C2           0.609103  0.552856
# C3           0.530308  0.455434
# C4           0.563505  0.479425
# C5           0.952617  0.964802
# ...               ...       ...
# C996         0.926769  0.945952
# C997         0.945150  0.951830
# C998         0.983524  0.984440
# C999         1.000000  0.977933
# C1000        0.977933  1.000000
#
# [1000 rows x 1000 columns]

# %%
similarity_df.head()
# Out:
# Customer_ID        C1        C2        C3        C4        C5        C6  \
# Customer_ID
# C1           1.000000  0.880988  0.977922  0.910832  0.605865  0.470122
# C2           0.880988  1.000000  0.903726  0.971601  0.616182  0.593622
# C3           0.977922  0.903726  1.000000  0.955531  0.549353  0.436533
# C4           0.910832  0.971601  0.955531  1.000000  0.532249  0.512760
# C5           0.605865  0.616182  0.549353  0.532249  1.000000  0.931885
#
# Customer_ID        C7        C8        C9       C10  ...      C991      C992  \
# Customer_ID                                          ...
# C1           0.918236  0.639008  0.587765  0.994597  ...  0.494646  0.516999
# C2           0.995758  0.535402  0.535981  0.912832  ...  0.522932  0.572130
# C3           0.928173  0.553419  0.541393  0.966780  ...  0.414325  0.466264
# C4           0.971125  0.490299  0.502093  0.920121  ...  0.413505  0.488952
# C5           0.637399  0.958285  0.968982  0.640878  ...  0.982596  0.982085
#
# Customer_ID      C993      C994      C995      C996      C997      C998  \
# Customer_ID
# C1           0.985291  0.963380  0.438707  0.378662  0.538553  0.563497
# C2           0.910379  0.950279  0.473649  0.363199  0.496111  0.630824
# C3           0.944209  0.933228  0.362502  0.319649  0.484102  0.523669
# C4           0.906206  0.921540  0.394663  0.286194  0.434786  0.549816
# C5           0.652974  0.682707  0.927279  0.953739  0.982932  0.986323
#
# Customer_ID      C999     C1000
# Customer_ID
# C1           0.548643  0.515477
# C2           0.609103  0.552856
# C3           0.530308  0.455434
# C4           0.563505  0.479425
# C5           0.952617  0.964802
#
# [5 rows x 1000 columns]

# %%
array = similarity_df.to_numpy()

# %%
np.fill_diagonal(array, np.nan)

# %%
df_replaced = pd.DataFrame(array, columns=df.Customer_ID, index=df.Customer_ID)

# %%
df_replaced
# Out:
# Customer_ID        C1        C2        C3        C4        C5        C6  \
# Customer_ID
# C1                NaN  0.880988  0.977922  0.910832  0.605865  0.470122
# C2           0.880988       NaN  0.903726  0.971601  0.616182  0.593622
# C3           0.977922  0.903726       NaN  0.955531  0.549353  0.436533
# C4           0.910832  0.971601  0.955531       NaN  0.532249  0.512760
# C5           0.605865  0.616182  0.549353  0.532249       NaN  0.931885
# ...               ...       ...       ...       ...       ...       ...
# C996         0.378662  0.363199  0.319649  0.286194  0.953739  0.902289
# C997         0.538553  0.496111  0.484102  0.434786  0.982932  0.901803
# C998         0.563497  0.630824  0.523669  0.549816  0.986323  0.977257
# C999         0.548643  0.609103  0.530308  0.563505  0.952617  0.978346
# C1000        0.515477  0.552856  0.455434  0.479425  0.964802  0.982138
#
# Customer_ID        C7        C8        C9       C10  ...      C991      C992  \
# Customer_ID                                          ...
# C1           0.918236  0.639008  0.587765  0.994597  ...  0.494646  0.516999
# C2           0.995758  0.535402  0.535981  0.912832  ...  0.522932  0.572130
# C3           0.928173  0.553419  0.541393  0.966780  ...  0.414325  0.466264
# C4           0.971125  0.490299  0.502093  0.920121  ...  0.413505  0.488952
# C5           0.637399  0.958285  0.968982  0.640878  ...  0.982596  0.982085
# ...               ...       ...       ...       ...  ...       ...       ...
# C996         0.384569  0.929611  0.960158  0.405597  ...  0.961381  0.959015
# C997         0.523392  0.965357  0.986715  0.559882  ...  0.963967  0.966572
# C998         0.639351  0.933689  0.963305  0.603529  ...  0.974782  0.996276
# C999         0.613446  0.918394  0.969104  0.577437  ...  0.930708  0.980930
# C1000        0.565516  0.951898  0.965201  0.553233  ...  0.974241  0.993872
#
# Customer_ID      C993      C994      C995      C996      C997      C998  \
# Customer_ID
# C1           0.985291  0.963380  0.438707  0.378662  0.538553  0.563497
# C2           0.910379  0.950279  0.473649  0.363199  0.496111  0.630824
# C3           0.944209  0.933228  0.362502  0.319649  0.484102  0.523669
# C4           0.906206  0.921540  0.394663  0.286194  0.434786  0.549816
# C5           0.652974  0.682707  0.927279  0.953739  0.982932  0.986323
# ...               ...       ...       ...       ...       ...       ...
# C996         0.417028  0.438762  0.928197       NaN  0.983109  0.943694
# C997         0.565751  0.581597  0.917367  0.983109       NaN  0.962835
# C998         0.618324  0.654393  0.953108  0.943694  0.962835       NaN
# C999         0.586658  0.611133  0.947579  0.926769  0.945150  0.983524
# C1000        0.577578  0.595668  0.990401  0.945952  0.951830  0.984440
#
# Customer_ID      C999     C1000
# Customer_ID
# C1           0.548643  0.515477
# C2           0.609103  0.552856
# C3           0.530308  0.455434
# C4           0.563505  0.479425
# C5           0.952617  0.964802
# ...               ...       ...
# C996         0.926769  0.945952
# C997         0.945150  0.951830
# C998         0.983524  0.984440
# C999              NaN  0.977933
# C1000        0.977933       NaN
#
# [1000 rows x 1000 columns]

# %%
most_similar = df_replaced.idxmax(axis=1)

# %%
most_similar
# Out:
# Customer_ID
# C1       C605
# C2       C475
# C3       C661
# C4       C851
# C5       C130
#          ...
# C996     C467
# C997     C159
# C998     C839
# C999     C538
# C1000    C332
# Length: 1000, dtype: object

# %%
# LLM usage

# %%
api_key = "gsk_"
llm=ChatGroq(groq_api_key=api_key,model_name="Gemma2-9b-It")

# %%
prompt_template = PromptTemplate(
                                 
input_variables=["customer_id", "similar_customer", "calls", "sms", "data", "bill", "subscription"],

template="""
    A telecom customer {customer_id} has the following usage pattern:
    - Monthly Calls: {calls} mins
    - Monthly SMS: {sms}
    - Data Usage: {data} GB
    - Average Monthly Bill: ${bill}
    - Subscription Type: {subscription}

    Their most similar customer is {similar_customer}, who has a similar usage profile.
    
    Based on this, suggest a personalized offer for customer {customer_id} that aligns with their usage behavior.
    """
    
)

# %%
def generate_offer(customer):
    similar_customer = most_similar[customer]
    
    # Get feature values of the customer
    customer_data = df[df['Customer_ID'] == customer]
    if customer_data.empty:
        return 'error: customer not found'
    customer_data= customer_data.iloc[0]
    print(f"Generating offer for Customer: {customer}")
    print(f"Similar Customer: {similar_customer}")
    print(f"Customer Data: {customer_data.to_dict()}")
    
    # Fill the prompt
    prompt = prompt_template.format(
        customer_id=customer,
        similar_customer=similar_customer,
        calls=customer_data['Monthly_Calls'],
        sms=customer_data['Monthly_SMS'],
        data=round(customer_data['Data_Usage_GB'], 2),
        bill=round(customer_data['Average_Bill'], 2),
        subscription="Postpaid" if customer_data['Subscription_Type'] == 1 else "Prepaid"

    )

    print(f"Prompt for {customer}: {prompt}")
  
    #offer = llm(prompt)
    #return offer
    if not callable(llm):
        raise TypeError("llm is not callable. Check initialization.")

    try:
        offer = llm(prompt)
        print(f"Offer for {customer}: {offer}")  # Debugging output
    except Exception as e:
        return f"LLM Error: {e}"

    # Debugging: Ensure output is a string
    if not isinstance(offer, str):
        return f"Error: Unexpected return type from LLM - {type(offer)}"

    return offer
  




    #offer = llm(prompt)
    #return offer

# %%
df['Recommended_Offer'] = df['Customer_ID'].apply(lambda x: generate_offer(x))
# Out:
# Generating offer for Customer: C1
# Similar Customer: C605
# Customer Data: {'Customer_ID': 'C1', 'Monthly_Calls': 443, 'Monthly_SMS': 38, 'Data_Usage_GB': 16.0921932476633, 'Subscription_Type': 0, 'Average_Bill': 37.27128243756963, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C1:
#     A telecom customer C1 has the following usage pattern:
#     - Monthly Calls: 443 mins
#     - Monthly SMS: 38
#     - Data Usage: 16.09 GB
#     - Average Monthly Bill: $37.27
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C605, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C1 that aligns with their usage behavior.
#
# Generating offer for Customer: C2
# Similar Customer: C475
# Customer Data: {'Customer_ID': 'C2', 'Monthly_Calls': 546, 'Monthly_SMS': 27, 'Data_Usage_GB': 4.297761334848371, 'Subscription_Type': 0, 'Average_Bill': 51.38649173053231, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C2:
#     A telecom customer C2 has the following usage pattern:
#     - Monthly Calls: 546 mins
#     - Monthly SMS: 27
#     - Data Usage: 4.3 GB
#     - Average Monthly Bill: $51.39
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C475, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C2 that aligns with their usage behavior.
#
# Generating offer for Customer: C3
# Similar Customer: C661
# Customer Data: {'Customer_ID': 'C3', 'Monthly_Calls': 341, 'Monthly_SMS': 30, 'Data_Usage_GB': 7.739410166708134, 'Subscription_Type': 0, 'Average_Bill': 20.332755184011827, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C3:
#     A telecom customer C3 has the following usage pattern:
#     - Monthly Calls: 341 mins
#     - Monthly SMS: 30
#     - Data Usage: 7.74 GB
#     - Average Monthly Bill: $20.33
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C661, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C3 that aligns with their usage behavior.
#
# Generating offer for Customer: C4
# Similar Customer: C851
# Customer Data: {'Customer_ID': 'C4', 'Monthly_Calls': 424, 'Monthly_SMS': 25, 'Data_Usage_GB': 5.75438720163296, 'Subscription_Type': 0, 'Average_Bill': 25.6438307854811, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C4:
#     A telecom customer C4 has the following usage pattern:
#     - Monthly Calls: 424 mins
#     - Monthly SMS: 25
#     - Data Usage: 5.75 GB
#     - Average Monthly Bill: $25.64
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C851, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C4 that aligns with their usage behavior.
#
# Generating offer for Customer: C5
# Similar Customer: C130
# Customer Data: {'Customer_ID': 'C5', 'Monthly_Calls': 295, 'Monthly_SMS': 35, 'Data_Usage_GB': 5.823837898224798, 'Subscription_Type': 1, 'Average_Bill': 92.98528720412091, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C5:
#     A telecom customer C5 has the following usage pattern:
#     - Monthly Calls: 295 mins
#     - Monthly SMS: 35
#     - Data Usage: 5.82 GB
#     - Average Monthly Bill: $92.99
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C130, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C5 that aligns with their usage behavior.
#
# Generating offer for Customer: C6
# Similar Customer: C545
# Customer Data: {'Customer_ID': 'C6', 'Monthly_Calls': 373, 'Monthly_SMS': 19, 'Data_Usage_GB': 6.818038899086579, 'Subscription_Type': 1, 'Average_Bill': 80.37342701886651, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C6:
#     A telecom customer C6 has the following usage pattern:
#     - Monthly Calls: 373 mins
#     - Monthly SMS: 19
#     - Data Usage: 6.82 GB
#     - Average Monthly Bill: $80.37
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C545, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C6 that aligns with their usage behavior.
#
# Generating offer for Customer: C7
# Similar Customer: C475
# Customer Data: {'Customer_ID': 'C7', 'Monthly_Calls': 479, 'Monthly_SMS': 28, 'Data_Usage_GB': 5.899001730063439, 'Subscription_Type': 0, 'Average_Bill': 48.74968316927731, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C7:
#     A telecom customer C7 has the following usage pattern:
#     - Monthly Calls: 479 mins
#     - Monthly SMS: 28
#     - Data Usage: 5.9 GB
#     - Average Monthly Bill: $48.75
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C475, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C7 that aligns with their usage behavior.
#
# Generating offer for Customer: C8
# Similar Customer: C123
# Customer Data: {'Customer_ID': 'C8', 'Monthly_Calls': 213, 'Monthly_SMS': 36, 'Data_Usage_GB': 20.034176193943875, 'Subscription_Type': 1, 'Average_Bill': 77.31355410695889, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C8:
#     A telecom customer C8 has the following usage pattern:
#     - Monthly Calls: 213 mins
#     - Monthly SMS: 36
#     - Data Usage: 20.03 GB
#     - Average Monthly Bill: $77.31
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C123, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C8 that aligns with their usage behavior.
#
# Generating offer for Customer: C9
# Similar Customer: C729
# Customer Data: {'Customer_ID': 'C9', 'Monthly_Calls': 242, 'Monthly_SMS': 32, 'Data_Usage_GB': 10.484715340360243, 'Subscription_Type': 1, 'Average_Bill': 57.23017808038151, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C9:
#     A telecom customer C9 has the following usage pattern:
#     - Monthly Calls: 242 mins
#     - Monthly SMS: 32
#     - Data Usage: 10.48 GB
#     - Average Monthly Bill: $57.23
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C729, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C9 that aligns with their usage behavior.
#
# Generating offer for Customer: C10
# Similar Customer: C90
# Customer Data: {'Customer_ID': 'C10', 'Monthly_Calls': 353, 'Monthly_SMS': 32, 'Data_Usage_GB': 12.072833317098398, 'Subscription_Type': 0, 'Average_Bill': 39.66253398256, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C10:
#     A telecom customer C10 has the following usage pattern:
#     - Monthly Calls: 353 mins
#     - Monthly SMS: 32
#     - Data Usage: 12.07 GB
#     - Average Monthly Bill: $39.66
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C90, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C10 that aligns with their usage behavior.
#
# Generating offer for Customer: C11
# Similar Customer: C464
# Customer Data: {'Customer_ID': 'C11', 'Monthly_Calls': 347, 'Monthly_SMS': 33, 'Data_Usage_GB': 5.6574636478331914, 'Subscription_Type': 1, 'Average_Bill': 61.43040520298598, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C11:
#     A telecom customer C11 has the following usage pattern:
#     - Monthly Calls: 347 mins
#     - Monthly SMS: 33
#     - Data Usage: 5.66 GB
#     - Average Monthly Bill: $61.43
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C464, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C11 that aligns with their usage behavior.
#
# Generating offer for Customer: C12
# Similar Customer: C864
# Customer Data: {'Customer_ID': 'C12', 'Monthly_Calls': 282, 'Monthly_SMS': 22, 'Data_Usage_GB': 14.398105360319414, 'Subscription_Type': 0, 'Average_Bill': 19.80240818755892, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C12:
#     A telecom customer C12 has the following usage pattern:
#     - Monthly Calls: 282 mins
#     - Monthly SMS: 22
#     - Data Usage: 14.4 GB
#     - Average Monthly Bill: $19.8
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C864, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C12 that aligns with their usage behavior.
#
# Generating offer for Customer: C13
# Similar Customer: C613
# Customer Data: {'Customer_ID': 'C13', 'Monthly_Calls': 168, 'Monthly_SMS': 30, 'Data_Usage_GB': 21.944312618378277, 'Subscription_Type': 1, 'Average_Bill': 63.033627101951126, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C13:
#     A telecom customer C13 has the following usage pattern:
#     - Monthly Calls: 168 mins
#     - Monthly SMS: 30
#     - Data Usage: 21.94 GB
#     - Average Monthly Bill: $63.03
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C613, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C13 that aligns with their usage behavior.
#
# Generating offer for Customer: C14
# Similar Customer: C80
# Customer Data: {'Customer_ID': 'C14', 'Monthly_Calls': 228, 'Monthly_SMS': 24, 'Data_Usage_GB': 3.245342192380956, 'Subscription_Type': 0, 'Average_Bill': 38.11687713227967, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C14:
#     A telecom customer C14 has the following usage pattern:
#     - Monthly Calls: 228 mins
#     - Monthly SMS: 24
#     - Data Usage: 3.25 GB
#     - Average Monthly Bill: $38.12
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C80, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C14 that aligns with their usage behavior.
#
# Generating offer for Customer: C15
# Similar Customer: C880
# Customer Data: {'Customer_ID': 'C15', 'Monthly_Calls': 396, 'Monthly_SMS': 32, 'Data_Usage_GB': 6.640495895070509, 'Subscription_Type': 1, 'Average_Bill': 65.69954883416297, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C15:
#     A telecom customer C15 has the following usage pattern:
#     - Monthly Calls: 396 mins
#     - Monthly SMS: 32
#     - Data Usage: 6.64 GB
#     - Average Monthly Bill: $65.7
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C880, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C15 that aligns with their usage behavior.
#
# Generating offer for Customer: C16
# Similar Customer: C161
# Customer Data: {'Customer_ID': 'C16', 'Monthly_Calls': 399, 'Monthly_SMS': 37, 'Data_Usage_GB': 10.620691653598016, 'Subscription_Type': 0, 'Average_Bill': 50.12087489304073, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C16:
#     A telecom customer C16 has the following usage pattern:
#     - Monthly Calls: 399 mins
#     - Monthly SMS: 37
#     - Data Usage: 10.62 GB
#     - Average Monthly Bill: $50.12
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C161, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C16 that aligns with their usage behavior.
#
# Generating offer for Customer: C17
# Similar Customer: C195
# Customer Data: {'Customer_ID': 'C17', 'Monthly_Calls': 247, 'Monthly_SMS': 27, 'Data_Usage_GB': 15.412292118660355, 'Subscription_Type': 0, 'Average_Bill': 41.9527999395023, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C17:
#     A telecom customer C17 has the following usage pattern:
#     - Monthly Calls: 247 mins
#     - Monthly SMS: 27
#     - Data Usage: 15.41 GB
#     - Average Monthly Bill: $41.95
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C195, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C17 that aligns with their usage behavior.
#
# Generating offer for Customer: C18
# Similar Customer: C881
# Customer Data: {'Customer_ID': 'C18', 'Monthly_Calls': 225, 'Monthly_SMS': 28, 'Data_Usage_GB': 5.202260864038806, 'Subscription_Type': 1, 'Average_Bill': 50.79147387402443, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C18:
#     A telecom customer C18 has the following usage pattern:
#     - Monthly Calls: 225 mins
#     - Monthly SMS: 28
#     - Data Usage: 5.2 GB
#     - Average Monthly Bill: $50.79
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C881, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C18 that aligns with their usage behavior.
#
# Generating offer for Customer: C19
# Similar Customer: C396
# Customer Data: {'Customer_ID': 'C19', 'Monthly_Calls': 202, 'Monthly_SMS': 26, 'Data_Usage_GB': 14.98539897335713, 'Subscription_Type': 1, 'Average_Bill': 60.4993149930905, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C19:
#     A telecom customer C19 has the following usage pattern:
#     - Monthly Calls: 202 mins
#     - Monthly SMS: 26
#     - Data Usage: 14.99 GB
#     - Average Monthly Bill: $60.5
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C396, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C19 that aligns with their usage behavior.
#
# Generating offer for Customer: C20
# Similar Customer: C283
# Customer Data: {'Customer_ID': 'C20', 'Monthly_Calls': 335, 'Monthly_SMS': 36, 'Data_Usage_GB': 5.391437949735127, 'Subscription_Type': 0, 'Average_Bill': 52.27961543662957, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C20:
#     A telecom customer C20 has the following usage pattern:
#     - Monthly Calls: 335 mins
#     - Monthly SMS: 36
#     - Data Usage: 5.39 GB
#     - Average Monthly Bill: $52.28
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C283, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C20 that aligns with their usage behavior.
#
# Generating offer for Customer: C21
# Similar Customer: C233
# Customer Data: {'Customer_ID': 'C21', 'Monthly_Calls': 252, 'Monthly_SMS': 32, 'Data_Usage_GB': 11.654203655136602, 'Subscription_Type': 1, 'Average_Bill': 69.40342012940405, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C21:
#     A telecom customer C21 has the following usage pattern:
#     - Monthly Calls: 252 mins
#     - Monthly SMS: 32
#     - Data Usage: 11.65 GB
#     - Average Monthly Bill: $69.4
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C233, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C21 that aligns with their usage behavior.
#
# Generating offer for Customer: C22
# Similar Customer: C929
# Customer Data: {'Customer_ID': 'C22', 'Monthly_Calls': 361, 'Monthly_SMS': 32, 'Data_Usage_GB': 6.949439838151962, 'Subscription_Type': 0, 'Average_Bill': 47.56824344799882, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C22:
#     A telecom customer C22 has the following usage pattern:
#     - Monthly Calls: 361 mins
#     - Monthly SMS: 32
#     - Data Usage: 6.95 GB
#     - Average Monthly Bill: $47.57
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C929, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C22 that aligns with their usage behavior.
#
# Generating offer for Customer: C23
# Similar Customer: C87
# Customer Data: {'Customer_ID': 'C23', 'Monthly_Calls': 228, 'Monthly_SMS': 29, 'Data_Usage_GB': 4.2001129529423835, 'Subscription_Type': 1, 'Average_Bill': 62.79536643919419, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C23:
#     A telecom customer C23 has the following usage pattern:
#     - Monthly Calls: 228 mins
#     - Monthly SMS: 29
#     - Data Usage: 4.2 GB
#     - Average Monthly Bill: $62.8
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C87, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C23 that aligns with their usage behavior.
#
# Generating offer for Customer: C24
# Similar Customer: C810
# Customer Data: {'Customer_ID': 'C24', 'Monthly_Calls': 449, 'Monthly_SMS': 30, 'Data_Usage_GB': 12.560692074514078, 'Subscription_Type': 1, 'Average_Bill': 71.95809296431668, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C24:
#     A telecom customer C24 has the following usage pattern:
#     - Monthly Calls: 449 mins
#     - Monthly SMS: 30
#     - Data Usage: 12.56 GB
#     - Average Monthly Bill: $71.96
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C810, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C24 that aligns with their usage behavior.
#
# Generating offer for Customer: C25
# Similar Customer: C736
# Customer Data: {'Customer_ID': 'C25', 'Monthly_Calls': 240, 'Monthly_SMS': 19, 'Data_Usage_GB': 5.7549652770281154, 'Subscription_Type': 1, 'Average_Bill': 77.13582474494629, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C25:
#     A telecom customer C25 has the following usage pattern:
#     - Monthly Calls: 240 mins
#     - Monthly SMS: 19
#     - Data Usage: 5.75 GB
#     - Average Monthly Bill: $77.14
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C736, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C25 that aligns with their usage behavior.
#
# Generating offer for Customer: C26
# Similar Customer: C622
# Customer Data: {'Customer_ID': 'C26', 'Monthly_Calls': 208, 'Monthly_SMS': 20, 'Data_Usage_GB': 6.200072321240551, 'Subscription_Type': 0, 'Average_Bill': 42.19082268622897, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C26:
#     A telecom customer C26 has the following usage pattern:
#     - Monthly Calls: 208 mins
#     - Monthly SMS: 20
#     - Data Usage: 6.2 GB
#     - Average Monthly Bill: $42.19
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C622, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C26 that aligns with their usage behavior.
#
# Generating offer for Customer: C27
# Similar Customer: C348
# Customer Data: {'Customer_ID': 'C27', 'Monthly_Calls': 303, 'Monthly_SMS': 31, 'Data_Usage_GB': 9.317339977019117, 'Subscription_Type': 0, 'Average_Bill': 48.794036375477795, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C27:
#     A telecom customer C27 has the following usage pattern:
#     - Monthly Calls: 303 mins
#     - Monthly SMS: 31
#     - Data Usage: 9.32 GB
#     - Average Monthly Bill: $48.79
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C348, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C27 that aligns with their usage behavior.
#
# Generating offer for Customer: C28
# Similar Customer: C202
# Customer Data: {'Customer_ID': 'C28', 'Monthly_Calls': 301, 'Monthly_SMS': 28, 'Data_Usage_GB': 7.795128384558133, 'Subscription_Type': 1, 'Average_Bill': 80.83776287683432, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C28:
#     A telecom customer C28 has the following usage pattern:
#     - Monthly Calls: 301 mins
#     - Monthly SMS: 28
#     - Data Usage: 7.8 GB
#     - Average Monthly Bill: $80.84
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C202, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C28 that aligns with their usage behavior.
#
# Generating offer for Customer: C29
# Similar Customer: C298
# Customer Data: {'Customer_ID': 'C29', 'Monthly_Calls': 291, 'Monthly_SMS': 35, 'Data_Usage_GB': 14.468701406406092, 'Subscription_Type': 0, 'Average_Bill': 42.79815733880269, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C29:
#     A telecom customer C29 has the following usage pattern:
#     - Monthly Calls: 291 mins
#     - Monthly SMS: 35
#     - Data Usage: 14.47 GB
#     - Average Monthly Bill: $42.8
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C298, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C29 that aligns with their usage behavior.
#
# Generating offer for Customer: C30
# Similar Customer: C515
# Customer Data: {'Customer_ID': 'C30', 'Monthly_Calls': 190, 'Monthly_SMS': 31, 'Data_Usage_GB': 10.682897077383842, 'Subscription_Type': 0, 'Average_Bill': 38.02954853745321, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C30:
#     A telecom customer C30 has the following usage pattern:
#     - Monthly Calls: 190 mins
#     - Monthly SMS: 31
#     - Data Usage: 10.68 GB
#     - Average Monthly Bill: $38.03
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C515, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C30 that aligns with their usage behavior.
#
# Generating offer for Customer: C31
# Similar Customer: C921
# Customer Data: {'Customer_ID': 'C31', 'Monthly_Calls': 571, 'Monthly_SMS': 25, 'Data_Usage_GB': 4.379393343318782, 'Subscription_Type': 1, 'Average_Bill': 83.29277802038736, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C31:
#     A telecom customer C31 has the following usage pattern:
#     - Monthly Calls: 571 mins
#     - Monthly SMS: 25
#     - Data Usage: 4.38 GB
#     - Average Monthly Bill: $83.29
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C921, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C31 that aligns with their usage behavior.
#
# Generating offer for Customer: C32
# Similar Customer: C221
# Customer Data: {'Customer_ID': 'C32', 'Monthly_Calls': 451, 'Monthly_SMS': 28, 'Data_Usage_GB': 4.2036376320556075, 'Subscription_Type': 1, 'Average_Bill': 60.991496459044505, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C32:
#     A telecom customer C32 has the following usage pattern:
#     - Monthly Calls: 451 mins
#     - Monthly SMS: 28
#     - Data Usage: 4.2 GB
#     - Average Monthly Bill: $60.99
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C221, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C32 that aligns with their usage behavior.
#
# Generating offer for Customer: C33
# Similar Customer: C939
# Customer Data: {'Customer_ID': 'C33', 'Monthly_Calls': 219, 'Monthly_SMS': 23, 'Data_Usage_GB': 4.666940949056912, 'Subscription_Type': 0, 'Average_Bill': 44.28045461886396, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C33:
#     A telecom customer C33 has the following usage pattern:
#     - Monthly Calls: 219 mins
#     - Monthly SMS: 23
#     - Data Usage: 4.67 GB
#     - Average Monthly Bill: $44.28
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C939, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C33 that aligns with their usage behavior.
#
# Generating offer for Customer: C34
# Similar Customer: C797
# Customer Data: {'Customer_ID': 'C34', 'Monthly_Calls': 255, 'Monthly_SMS': 28, 'Data_Usage_GB': 10.851389557254961, 'Subscription_Type': 1, 'Average_Bill': 101.25737388673679, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C34:
#     A telecom customer C34 has the following usage pattern:
#     - Monthly Calls: 255 mins
#     - Monthly SMS: 28
#     - Data Usage: 10.85 GB
#     - Average Monthly Bill: $101.26
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C797, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C34 that aligns with their usage behavior.
#
# Generating offer for Customer: C35
# Similar Customer: C413
# Customer Data: {'Customer_ID': 'C35', 'Monthly_Calls': 339, 'Monthly_SMS': 34, 'Data_Usage_GB': 13.000317393556964, 'Subscription_Type': 0, 'Average_Bill': 38.87627434562396, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C35:
#     A telecom customer C35 has the following usage pattern:
#     - Monthly Calls: 339 mins
#     - Monthly SMS: 34
#     - Data Usage: 13.0 GB
#     - Average Monthly Bill: $38.88
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C413, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C35 that aligns with their usage behavior.
#
# Generating offer for Customer: C36
# Similar Customer: C208
# Customer Data: {'Customer_ID': 'C36', 'Monthly_Calls': 209, 'Monthly_SMS': 28, 'Data_Usage_GB': 19.24007119750444, 'Subscription_Type': 1, 'Average_Bill': 77.82487427941159, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C36:
#     A telecom customer C36 has the following usage pattern:
#     - Monthly Calls: 209 mins
#     - Monthly SMS: 28
#     - Data Usage: 19.24 GB
#     - Average Monthly Bill: $77.82
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C208, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C36 that aligns with their usage behavior.
#
# Generating offer for Customer: C37
# Similar Customer: C601
# Customer Data: {'Customer_ID': 'C37', 'Monthly_Calls': 333, 'Monthly_SMS': 25, 'Data_Usage_GB': 5.317425164953343, 'Subscription_Type': 1, 'Average_Bill': 74.66151680172125, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C37:
#     A telecom customer C37 has the following usage pattern:
#     - Monthly Calls: 333 mins
#     - Monthly SMS: 25
#     - Data Usage: 5.32 GB
#     - Average Monthly Bill: $74.66
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C601, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C37 that aligns with their usage behavior.
#
# Generating offer for Customer: C38
# Similar Customer: C872
# Customer Data: {'Customer_ID': 'C38', 'Monthly_Calls': 526, 'Monthly_SMS': 33, 'Data_Usage_GB': 11.095994401319988, 'Subscription_Type': 0, 'Average_Bill': 36.718895498527814, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C38:
#     A telecom customer C38 has the following usage pattern:
#     - Monthly Calls: 526 mins
#     - Monthly SMS: 33
#     - Data Usage: 11.1 GB
#     - Average Monthly Bill: $36.72
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C872, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C38 that aligns with their usage behavior.
#
# Generating offer for Customer: C39
# Similar Customer: C218
# Customer Data: {'Customer_ID': 'C39', 'Monthly_Calls': 427, 'Monthly_SMS': 29, 'Data_Usage_GB': 4.7458387359004846, 'Subscription_Type': 1, 'Average_Bill': 75.04131116574149, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C39:
#     A telecom customer C39 has the following usage pattern:
#     - Monthly Calls: 427 mins
#     - Monthly SMS: 29
#     - Data Usage: 4.75 GB
#     - Average Monthly Bill: $75.04
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C218, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C39 that aligns with their usage behavior.
#
# Generating offer for Customer: C40
# Similar Customer: C326
# Customer Data: {'Customer_ID': 'C40', 'Monthly_Calls': 112, 'Monthly_SMS': 29, 'Data_Usage_GB': 17.1793789004795, 'Subscription_Type': 1, 'Average_Bill': 84.41885829845207, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C40:
#     A telecom customer C40 has the following usage pattern:
#     - Monthly Calls: 112 mins
#     - Monthly SMS: 29
#     - Data Usage: 17.18 GB
#     - Average Monthly Bill: $84.42
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C326, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C40 that aligns with their usage behavior.
#
# Generating offer for Customer: C41
# Similar Customer: C562
# Customer Data: {'Customer_ID': 'C41', 'Monthly_Calls': 333, 'Monthly_SMS': 38, 'Data_Usage_GB': 8.688297297076783, 'Subscription_Type': 1, 'Average_Bill': 66.9927901615219, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C41:
#     A telecom customer C41 has the following usage pattern:
#     - Monthly Calls: 333 mins
#     - Monthly SMS: 38
#     - Data Usage: 8.69 GB
#     - Average Monthly Bill: $66.99
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C562, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C41 that aligns with their usage behavior.
#
# Generating offer for Customer: C42
# Similar Customer: C778
# Customer Data: {'Customer_ID': 'C42', 'Monthly_Calls': 184, 'Monthly_SMS': 24, 'Data_Usage_GB': 9.522214887308222, 'Subscription_Type': 0, 'Average_Bill': 37.96418896286418, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C42:
#     A telecom customer C42 has the following usage pattern:
#     - Monthly Calls: 184 mins
#     - Monthly SMS: 24
#     - Data Usage: 9.52 GB
#     - Average Monthly Bill: $37.96
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C778, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C42 that aligns with their usage behavior.
#
# Generating offer for Customer: C43
# Similar Customer: C609
# Customer Data: {'Customer_ID': 'C43', 'Monthly_Calls': 404, 'Monthly_SMS': 30, 'Data_Usage_GB': 6.88904469029348, 'Subscription_Type': 1, 'Average_Bill': 54.71525159562228, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C43:
#     A telecom customer C43 has the following usage pattern:
#     - Monthly Calls: 404 mins
#     - Monthly SMS: 30
#     - Data Usage: 6.89 GB
#     - Average Monthly Bill: $54.72
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C609, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C43 that aligns with their usage behavior.
#
# Generating offer for Customer: C44
# Similar Customer: C308
# Customer Data: {'Customer_ID': 'C44', 'Monthly_Calls': 141, 'Monthly_SMS': 25, 'Data_Usage_GB': 8.262316887087957, 'Subscription_Type': 0, 'Average_Bill': 45.28075978695131, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C44:
#     A telecom customer C44 has the following usage pattern:
#     - Monthly Calls: 141 mins
#     - Monthly SMS: 25
#     - Data Usage: 8.26 GB
#     - Average Monthly Bill: $45.28
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C308, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C44 that aligns with their usage behavior.
#
# Generating offer for Customer: C45
# Similar Customer: C737
# Customer Data: {'Customer_ID': 'C45', 'Monthly_Calls': 406, 'Monthly_SMS': 27, 'Data_Usage_GB': 12.696799481534706, 'Subscription_Type': 1, 'Average_Bill': 71.09669500772257, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C45:
#     A telecom customer C45 has the following usage pattern:
#     - Monthly Calls: 406 mins
#     - Monthly SMS: 27
#     - Data Usage: 12.7 GB
#     - Average Monthly Bill: $71.1
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C737, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C45 that aligns with their usage behavior.
#
# Generating offer for Customer: C46
# Similar Customer: C495
# Customer Data: {'Customer_ID': 'C46', 'Monthly_Calls': 258, 'Monthly_SMS': 22, 'Data_Usage_GB': 7.6591931088668455, 'Subscription_Type': 1, 'Average_Bill': 61.93812180429654, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C46:
#     A telecom customer C46 has the following usage pattern:
#     - Monthly Calls: 258 mins
#     - Monthly SMS: 22
#     - Data Usage: 7.66 GB
#     - Average Monthly Bill: $61.94
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C495, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C46 that aligns with their usage behavior.
#
# Generating offer for Customer: C47
# Similar Customer: C627
# Customer Data: {'Customer_ID': 'C47', 'Monthly_Calls': 145, 'Monthly_SMS': 29, 'Data_Usage_GB': 6.762394363274691, 'Subscription_Type': 0, 'Average_Bill': 31.728097974752377, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C47:
#     A telecom customer C47 has the following usage pattern:
#     - Monthly Calls: 145 mins
#     - Monthly SMS: 29
#     - Data Usage: 6.76 GB
#     - Average Monthly Bill: $31.73
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C627, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C47 that aligns with their usage behavior.
#
# Generating offer for Customer: C48
# Similar Customer: C179
# Customer Data: {'Customer_ID': 'C48', 'Monthly_Calls': 397, 'Monthly_SMS': 35, 'Data_Usage_GB': 5.777546553003435, 'Subscription_Type': 1, 'Average_Bill': 97.5462783513119, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C48:
#     A telecom customer C48 has the following usage pattern:
#     - Monthly Calls: 397 mins
#     - Monthly SMS: 35
#     - Data Usage: 5.78 GB
#     - Average Monthly Bill: $97.55
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C179, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C48 that aligns with their usage behavior.
#
# Generating offer for Customer: C49
# Similar Customer: C786
# Customer Data: {'Customer_ID': 'C49', 'Monthly_Calls': 376, 'Monthly_SMS': 35, 'Data_Usage_GB': 8.387209315710438, 'Subscription_Type': 0, 'Average_Bill': 24.52082457544615, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C49:
#     A telecom customer C49 has the following usage pattern:
#     - Monthly Calls: 376 mins
#     - Monthly SMS: 35
#     - Data Usage: 8.39 GB
#     - Average Monthly Bill: $24.52
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C786, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C49 that aligns with their usage behavior.
#
# Generating offer for Customer: C50
# Similar Customer: C537
# Customer Data: {'Customer_ID': 'C50', 'Monthly_Calls': 399, 'Monthly_SMS': 24, 'Data_Usage_GB': 6.757683053306539, 'Subscription_Type': 0, 'Average_Bill': 52.78186886820703, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C50:
#     A telecom customer C50 has the following usage pattern:
#     - Monthly Calls: 399 mins
#     - Monthly SMS: 24
#     - Data Usage: 6.76 GB
#     - Average Monthly Bill: $52.78
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C537, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C50 that aligns with their usage behavior.
#
# Generating offer for Customer: C51
# Similar Customer: C360
# Customer Data: {'Customer_ID': 'C51', 'Monthly_Calls': 163, 'Monthly_SMS': 28, 'Data_Usage_GB': 7.735100847481566, 'Subscription_Type': 0, 'Average_Bill': 42.2008947540769, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C51:
#     A telecom customer C51 has the following usage pattern:
#     - Monthly Calls: 163 mins
#     - Monthly SMS: 28
#     - Data Usage: 7.74 GB
#     - Average Monthly Bill: $42.2
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C360, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C51 that aligns with their usage behavior.
#
# Generating offer for Customer: C52
# Similar Customer: C537
# Customer Data: {'Customer_ID': 'C52', 'Monthly_Calls': 443, 'Monthly_SMS': 25, 'Data_Usage_GB': 5.323877404450033, 'Subscription_Type': 0, 'Average_Bill': 55.31407772426604, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C52:
#     A telecom customer C52 has the following usage pattern:
#     - Monthly Calls: 443 mins
#     - Monthly SMS: 25
#     - Data Usage: 5.32 GB
#     - Average Monthly Bill: $55.31
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C537, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C52 that aligns with their usage behavior.
#
# Generating offer for Customer: C53
# Similar Customer: C557
# Customer Data: {'Customer_ID': 'C53', 'Monthly_Calls': 517, 'Monthly_SMS': 30, 'Data_Usage_GB': 8.04575983510929, 'Subscription_Type': 1, 'Average_Bill': 75.23489709326087, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C53:
#     A telecom customer C53 has the following usage pattern:
#     - Monthly Calls: 517 mins
#     - Monthly SMS: 30
#     - Data Usage: 8.05 GB
#     - Average Monthly Bill: $75.23
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C557, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C53 that aligns with their usage behavior.
#
# Generating offer for Customer: C54
# Similar Customer: C722
# Customer Data: {'Customer_ID': 'C54', 'Monthly_Calls': 309, 'Monthly_SMS': 27, 'Data_Usage_GB': 11.00876584738696, 'Subscription_Type': 1, 'Average_Bill': 68.47042544233234, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C54:
#     A telecom customer C54 has the following usage pattern:
#     - Monthly Calls: 309 mins
#     - Monthly SMS: 27
#     - Data Usage: 11.01 GB
#     - Average Monthly Bill: $68.47
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C722, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C54 that aligns with their usage behavior.
#
# Generating offer for Customer: C55
# Similar Customer: C220
# Customer Data: {'Customer_ID': 'C55', 'Monthly_Calls': 310, 'Monthly_SMS': 31, 'Data_Usage_GB': 3.0570065354766647, 'Subscription_Type': 0, 'Average_Bill': 51.439155119665074, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C55:
#     A telecom customer C55 has the following usage pattern:
#     - Monthly Calls: 310 mins
#     - Monthly SMS: 31
#     - Data Usage: 3.06 GB
#     - Average Monthly Bill: $51.44
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C220, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C55 that aligns with their usage behavior.
#
# Generating offer for Customer: C56
# Similar Customer: C660
# Customer Data: {'Customer_ID': 'C56', 'Monthly_Calls': 340, 'Monthly_SMS': 26, 'Data_Usage_GB': 10.760187179144134, 'Subscription_Type': 1, 'Average_Bill': 72.92590609960327, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C56:
#     A telecom customer C56 has the following usage pattern:
#     - Monthly Calls: 340 mins
#     - Monthly SMS: 26
#     - Data Usage: 10.76 GB
#     - Average Monthly Bill: $72.93
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C660, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C56 that aligns with their usage behavior.
#
# Generating offer for Customer: C57
# Similar Customer: C893
# Customer Data: {'Customer_ID': 'C57', 'Monthly_Calls': 155, 'Monthly_SMS': 25, 'Data_Usage_GB': 9.33908839746944, 'Subscription_Type': 1, 'Average_Bill': 78.39143180881857, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C57:
#     A telecom customer C57 has the following usage pattern:
#     - Monthly Calls: 155 mins
#     - Monthly SMS: 25
#     - Data Usage: 9.34 GB
#     - Average Monthly Bill: $78.39
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C893, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C57 that aligns with their usage behavior.
#
# Generating offer for Customer: C58
# Similar Customer: C732
# Customer Data: {'Customer_ID': 'C58', 'Monthly_Calls': 144, 'Monthly_SMS': 21, 'Data_Usage_GB': 7.005493730101272, 'Subscription_Type': 1, 'Average_Bill': 77.87856988196165, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C58:
#     A telecom customer C58 has the following usage pattern:
#     - Monthly Calls: 144 mins
#     - Monthly SMS: 21
#     - Data Usage: 7.01 GB
#     - Average Monthly Bill: $77.88
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C732, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C58 that aligns with their usage behavior.
#
# Generating offer for Customer: C59
# Similar Customer: C514
# Customer Data: {'Customer_ID': 'C59', 'Monthly_Calls': 224, 'Monthly_SMS': 33, 'Data_Usage_GB': 7.548318581601644, 'Subscription_Type': 0, 'Average_Bill': 38.090425149521266, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C59:
#     A telecom customer C59 has the following usage pattern:
#     - Monthly Calls: 224 mins
#     - Monthly SMS: 33
#     - Data Usage: 7.55 GB
#     - Average Monthly Bill: $38.09
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C514, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C59 that aligns with their usage behavior.
#
# Generating offer for Customer: C60
# Similar Customer: C182
# Customer Data: {'Customer_ID': 'C60', 'Monthly_Calls': 348, 'Monthly_SMS': 29, 'Data_Usage_GB': 5.7588864652103, 'Subscription_Type': 1, 'Average_Bill': 76.00237966057666, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C60:
#     A telecom customer C60 has the following usage pattern:
#     - Monthly Calls: 348 mins
#     - Monthly SMS: 29
#     - Data Usage: 5.76 GB
#     - Average Monthly Bill: $76.0
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C182, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C60 that aligns with their usage behavior.
#
# Generating offer for Customer: C61
# Similar Customer: C441
# Customer Data: {'Customer_ID': 'C61', 'Monthly_Calls': 364, 'Monthly_SMS': 30, 'Data_Usage_GB': 2.974684358109299, 'Subscription_Type': 0, 'Average_Bill': 36.25302075945637, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C61:
#     A telecom customer C61 has the following usage pattern:
#     - Monthly Calls: 364 mins
#     - Monthly SMS: 30
#     - Data Usage: 2.97 GB
#     - Average Monthly Bill: $36.25
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C441, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C61 that aligns with their usage behavior.
#
# Generating offer for Customer: C62
# Similar Customer: C120
# Customer Data: {'Customer_ID': 'C62', 'Monthly_Calls': 395, 'Monthly_SMS': 28, 'Data_Usage_GB': 10.311274331211978, 'Subscription_Type': 0, 'Average_Bill': 40.80062267917393, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C62:
#     A telecom customer C62 has the following usage pattern:
#     - Monthly Calls: 395 mins
#     - Monthly SMS: 28
#     - Data Usage: 10.31 GB
#     - Average Monthly Bill: $40.8
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C120, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C62 that aligns with their usage behavior.
#
# Generating offer for Customer: C63
# Similar Customer: C884
# Customer Data: {'Customer_ID': 'C63', 'Monthly_Calls': 299, 'Monthly_SMS': 27, 'Data_Usage_GB': 5.242343923674624, 'Subscription_Type': 0, 'Average_Bill': 22.876788466365333, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C63:
#     A telecom customer C63 has the following usage pattern:
#     - Monthly Calls: 299 mins
#     - Monthly SMS: 27
#     - Data Usage: 5.24 GB
#     - Average Monthly Bill: $22.88
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C884, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C63 that aligns with their usage behavior.
#
# Generating offer for Customer: C64
# Similar Customer: C352
# Customer Data: {'Customer_ID': 'C64', 'Monthly_Calls': 384, 'Monthly_SMS': 32, 'Data_Usage_GB': 11.170746152905787, 'Subscription_Type': 1, 'Average_Bill': 76.67042776131414, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C64:
#     A telecom customer C64 has the following usage pattern:
#     - Monthly Calls: 384 mins
#     - Monthly SMS: 32
#     - Data Usage: 11.17 GB
#     - Average Monthly Bill: $76.67
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C352, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C64 that aligns with their usage behavior.
#
# Generating offer for Customer: C65
# Similar Customer: C583
# Customer Data: {'Customer_ID': 'C65', 'Monthly_Calls': 394, 'Monthly_SMS': 24, 'Data_Usage_GB': 10.947897155231173, 'Subscription_Type': 1, 'Average_Bill': 98.78110696945691, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C65:
#     A telecom customer C65 has the following usage pattern:
#     - Monthly Calls: 394 mins
#     - Monthly SMS: 24
#     - Data Usage: 10.95 GB
#     - Average Monthly Bill: $98.78
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C583, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C65 that aligns with their usage behavior.
#
# Generating offer for Customer: C66
# Similar Customer: C725
# Customer Data: {'Customer_ID': 'C66', 'Monthly_Calls': 108, 'Monthly_SMS': 29, 'Data_Usage_GB': 15.218850844956462, 'Subscription_Type': 1, 'Average_Bill': 52.14249628024261, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C66:
#     A telecom customer C66 has the following usage pattern:
#     - Monthly Calls: 108 mins
#     - Monthly SMS: 29
#     - Data Usage: 15.22 GB
#     - Average Monthly Bill: $52.14
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C725, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C66 that aligns with their usage behavior.
#
# Generating offer for Customer: C67
# Similar Customer: C655
# Customer Data: {'Customer_ID': 'C67', 'Monthly_Calls': 447, 'Monthly_SMS': 27, 'Data_Usage_GB': 3.6112693081663125, 'Subscription_Type': 1, 'Average_Bill': 74.79329602254626, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C67:
#     A telecom customer C67 has the following usage pattern:
#     - Monthly Calls: 447 mins
#     - Monthly SMS: 27
#     - Data Usage: 3.61 GB
#     - Average Monthly Bill: $74.79
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C655, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C67 that aligns with their usage behavior.
#
# Generating offer for Customer: C68
# Similar Customer: C247
# Customer Data: {'Customer_ID': 'C68', 'Monthly_Calls': 265, 'Monthly_SMS': 30, 'Data_Usage_GB': 8.520762916860653, 'Subscription_Type': 1, 'Average_Bill': 82.00784902989282, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C68:
#     A telecom customer C68 has the following usage pattern:
#     - Monthly Calls: 265 mins
#     - Monthly SMS: 30
#     - Data Usage: 8.52 GB
#     - Average Monthly Bill: $82.01
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C247, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C68 that aligns with their usage behavior.
#
# Generating offer for Customer: C69
# Similar Customer: C817
# Customer Data: {'Customer_ID': 'C69', 'Monthly_Calls': 329, 'Monthly_SMS': 31, 'Data_Usage_GB': 14.642336594322284, 'Subscription_Type': 1, 'Average_Bill': 60.369638640800844, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C69:
#     A telecom customer C69 has the following usage pattern:
#     - Monthly Calls: 329 mins
#     - Monthly SMS: 31
#     - Data Usage: 14.64 GB
# ...
# Prompt for C978:
#     A telecom customer C978 has the following usage pattern:
#     - Monthly Calls: 144 mins
#     - Monthly SMS: 35
#     - Data Usage: 10.01 GB
#     - Average Monthly Bill: $47.37
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C425, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C978 that aligns with their usage behavior.
#
# Generating offer for Customer: C979
# Similar Customer: C45
# Customer Data: {'Customer_ID': 'C979', 'Monthly_Calls': 390, 'Monthly_SMS': 24, 'Data_Usage_GB': 13.843591832956404, 'Subscription_Type': 1, 'Average_Bill': 65.96154338086372, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C979:
#     A telecom customer C979 has the following usage pattern:
#     - Monthly Calls: 390 mins
#     - Monthly SMS: 24
#     - Data Usage: 13.84 GB
#     - Average Monthly Bill: $65.96
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C45, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C979 that aligns with their usage behavior.
#
# Generating offer for Customer: C980
# Similar Customer: C758
# Customer Data: {'Customer_ID': 'C980', 'Monthly_Calls': 397, 'Monthly_SMS': 24, 'Data_Usage_GB': 9.160932175328702, 'Subscription_Type': 1, 'Average_Bill': 65.18007460925261, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C980:
#     A telecom customer C980 has the following usage pattern:
#     - Monthly Calls: 397 mins
#     - Monthly SMS: 24
#     - Data Usage: 9.16 GB
#     - Average Monthly Bill: $65.18
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C758, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C980 that aligns with their usage behavior.
#
# Generating offer for Customer: C981
# Similar Customer: C82
# Customer Data: {'Customer_ID': 'C981', 'Monthly_Calls': 98, 'Monthly_SMS': 27, 'Data_Usage_GB': 13.197589858635597, 'Subscription_Type': 0, 'Average_Bill': 40.375405433388224, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C981:
#     A telecom customer C981 has the following usage pattern:
#     - Monthly Calls: 98 mins
#     - Monthly SMS: 27
#     - Data Usage: 13.2 GB
#     - Average Monthly Bill: $40.38
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C82, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C981 that aligns with their usage behavior.
#
# Generating offer for Customer: C982
# Similar Customer: C803
# Customer Data: {'Customer_ID': 'C982', 'Monthly_Calls': 401, 'Monthly_SMS': 38, 'Data_Usage_GB': 5.600514212808872, 'Subscription_Type': 1, 'Average_Bill': 61.38134747674194, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C982:
#     A telecom customer C982 has the following usage pattern:
#     - Monthly Calls: 401 mins
#     - Monthly SMS: 38
#     - Data Usage: 5.6 GB
#     - Average Monthly Bill: $61.38
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C803, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C982 that aligns with their usage behavior.
#
# Generating offer for Customer: C983
# Similar Customer: C446
# Customer Data: {'Customer_ID': 'C983', 'Monthly_Calls': 173, 'Monthly_SMS': 27, 'Data_Usage_GB': 4.976816331729476, 'Subscription_Type': 0, 'Average_Bill': 38.226850766077725, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C983:
#     A telecom customer C983 has the following usage pattern:
#     - Monthly Calls: 173 mins
#     - Monthly SMS: 27
#     - Data Usage: 4.98 GB
#     - Average Monthly Bill: $38.23
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C446, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C983 that aligns with their usage behavior.
#
# Generating offer for Customer: C984
# Similar Customer: C577
# Customer Data: {'Customer_ID': 'C984', 'Monthly_Calls': 225, 'Monthly_SMS': 24, 'Data_Usage_GB': 8.48514404426527, 'Subscription_Type': 0, 'Average_Bill': 35.30397405454625, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C984:
#     A telecom customer C984 has the following usage pattern:
#     - Monthly Calls: 225 mins
#     - Monthly SMS: 24
#     - Data Usage: 8.49 GB
#     - Average Monthly Bill: $35.3
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C577, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C984 that aligns with their usage behavior.
#
# Generating offer for Customer: C985
# Similar Customer: C736
# Customer Data: {'Customer_ID': 'C985', 'Monthly_Calls': 293, 'Monthly_SMS': 22, 'Data_Usage_GB': 5.3613310816053055, 'Subscription_Type': 1, 'Average_Bill': 77.86898989060323, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C985:
#     A telecom customer C985 has the following usage pattern:
#     - Monthly Calls: 293 mins
#     - Monthly SMS: 22
#     - Data Usage: 5.36 GB
#     - Average Monthly Bill: $77.87
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C736, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C985 that aligns with their usage behavior.
#
# Generating offer for Customer: C986
# Similar Customer: C11
# Customer Data: {'Customer_ID': 'C986', 'Monthly_Calls': 340, 'Monthly_SMS': 32, 'Data_Usage_GB': 7.101252982817214, 'Subscription_Type': 1, 'Average_Bill': 58.84427865841859, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C986:
#     A telecom customer C986 has the following usage pattern:
#     - Monthly Calls: 340 mins
#     - Monthly SMS: 32
#     - Data Usage: 7.1 GB
#     - Average Monthly Bill: $58.84
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C11, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C986 that aligns with their usage behavior.
#
# Generating offer for Customer: C987
# Similar Customer: C927
# Customer Data: {'Customer_ID': 'C987', 'Monthly_Calls': 415, 'Monthly_SMS': 35, 'Data_Usage_GB': 8.81712754054483, 'Subscription_Type': 1, 'Average_Bill': 92.55239339811999, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C987:
#     A telecom customer C987 has the following usage pattern:
#     - Monthly Calls: 415 mins
#     - Monthly SMS: 35
#     - Data Usage: 8.82 GB
#     - Average Monthly Bill: $92.55
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C927, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C987 that aligns with their usage behavior.
#
# Generating offer for Customer: C988
# Similar Customer: C429
# Customer Data: {'Customer_ID': 'C988', 'Monthly_Calls': 305, 'Monthly_SMS': 24, 'Data_Usage_GB': 7.062638358596451, 'Subscription_Type': 1, 'Average_Bill': 104.15102490294882, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C988:
#     A telecom customer C988 has the following usage pattern:
#     - Monthly Calls: 305 mins
#     - Monthly SMS: 24
#     - Data Usage: 7.06 GB
#     - Average Monthly Bill: $104.15
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C429, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C988 that aligns with their usage behavior.
#
# Generating offer for Customer: C989
# Similar Customer: C13
# Customer Data: {'Customer_ID': 'C989', 'Monthly_Calls': 143, 'Monthly_SMS': 25, 'Data_Usage_GB': 24.160344534672074, 'Subscription_Type': 1, 'Average_Bill': 37.766219524103924, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C989:
#     A telecom customer C989 has the following usage pattern:
#     - Monthly Calls: 143 mins
#     - Monthly SMS: 25
#     - Data Usage: 24.16 GB
#     - Average Monthly Bill: $37.77
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C13, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C989 that aligns with their usage behavior.
#
# Generating offer for Customer: C990
# Similar Customer: C838
# Customer Data: {'Customer_ID': 'C990', 'Monthly_Calls': 186, 'Monthly_SMS': 39, 'Data_Usage_GB': 7.236453879389702, 'Subscription_Type': 0, 'Average_Bill': 41.19673322698768, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C990:
#     A telecom customer C990 has the following usage pattern:
#     - Monthly Calls: 186 mins
#     - Monthly SMS: 39
#     - Data Usage: 7.24 GB
#     - Average Monthly Bill: $41.2
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C838, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C990 that aligns with their usage behavior.
#
# Generating offer for Customer: C991
# Similar Customer: C782
# Customer Data: {'Customer_ID': 'C991', 'Monthly_Calls': 193, 'Monthly_SMS': 29, 'Data_Usage_GB': 7.770722839093396, 'Subscription_Type': 1, 'Average_Bill': 103.57912500650431, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C991:
#     A telecom customer C991 has the following usage pattern:
#     - Monthly Calls: 193 mins
#     - Monthly SMS: 29
#     - Data Usage: 7.77 GB
#     - Average Monthly Bill: $103.58
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C782, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C991 that aligns with their usage behavior.
#
# Generating offer for Customer: C992
# Similar Customer: C859
# Customer Data: {'Customer_ID': 'C992', 'Monthly_Calls': 284, 'Monthly_SMS': 26, 'Data_Usage_GB': 6.7076548543791095, 'Subscription_Type': 1, 'Average_Bill': 82.39161397997688, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C992:
#     A telecom customer C992 has the following usage pattern:
#     - Monthly Calls: 284 mins
#     - Monthly SMS: 26
#     - Data Usage: 6.71 GB
#     - Average Monthly Bill: $82.39
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C859, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C992 that aligns with their usage behavior.
#
# Generating offer for Customer: C993
# Similar Customer: C90
# Customer Data: {'Customer_ID': 'C993', 'Monthly_Calls': 279, 'Monthly_SMS': 28, 'Data_Usage_GB': 11.191985321345406, 'Subscription_Type': 0, 'Average_Bill': 38.62002292148989, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C993:
#     A telecom customer C993 has the following usage pattern:
#     - Monthly Calls: 279 mins
#     - Monthly SMS: 28
#     - Data Usage: 11.19 GB
#     - Average Monthly Bill: $38.62
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C90, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C993 that aligns with their usage behavior.
#
# Generating offer for Customer: C994
# Similar Customer: C651
# Customer Data: {'Customer_ID': 'C994', 'Monthly_Calls': 232, 'Monthly_SMS': 25, 'Data_Usage_GB': 6.635493051767731, 'Subscription_Type': 0, 'Average_Bill': 37.22057981480461, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C994:
#     A telecom customer C994 has the following usage pattern:
#     - Monthly Calls: 232 mins
#     - Monthly SMS: 25
#     - Data Usage: 6.64 GB
#     - Average Monthly Bill: $37.22
#     - Subscription Type: Prepaid
#
#     Their most similar customer is C651, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C994 that aligns with their usage behavior.
#
# Generating offer for Customer: C995
# Similar Customer: C377
# Customer Data: {'Customer_ID': 'C995', 'Monthly_Calls': 218, 'Monthly_SMS': 20, 'Data_Usage_GB': 14.941033042641731, 'Subscription_Type': 1, 'Average_Bill': 81.02153372653474, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C995:
#     A telecom customer C995 has the following usage pattern:
#     - Monthly Calls: 218 mins
#     - Monthly SMS: 20
#     - Data Usage: 14.94 GB
#     - Average Monthly Bill: $81.02
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C377, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C995 that aligns with their usage behavior.
#
# Generating offer for Customer: C996
# Similar Customer: C467
# Customer Data: {'Customer_ID': 'C996', 'Monthly_Calls': 74, 'Monthly_SMS': 28, 'Data_Usage_GB': 3.3034175518815623, 'Subscription_Type': 1, 'Average_Bill': 65.4421892520669, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C996:
#     A telecom customer C996 has the following usage pattern:
#     - Monthly Calls: 74 mins
#     - Monthly SMS: 28
#     - Data Usage: 3.3 GB
#     - Average Monthly Bill: $65.44
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C467, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C996 that aligns with their usage behavior.
#
# Generating offer for Customer: C997
# Similar Customer: C159
# Customer Data: {'Customer_ID': 'C997', 'Monthly_Calls': 172, 'Monthly_SMS': 34, 'Data_Usage_GB': 5.704034541659266, 'Subscription_Type': 1, 'Average_Bill': 68.43424599967513, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C997:
#     A telecom customer C997 has the following usage pattern:
#     - Monthly Calls: 172 mins
#     - Monthly SMS: 34
#     - Data Usage: 5.7 GB
#     - Average Monthly Bill: $68.43
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C159, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C997 that aligns with their usage behavior.
#
# Generating offer for Customer: C998
# Similar Customer: C839
# Customer Data: {'Customer_ID': 'C998', 'Monthly_Calls': 351, 'Monthly_SMS': 28, 'Data_Usage_GB': 4.934610130828695, 'Subscription_Type': 1, 'Average_Bill': 84.88517575009756, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C998:
#     A telecom customer C998 has the following usage pattern:
#     - Monthly Calls: 351 mins
#     - Monthly SMS: 28
#     - Data Usage: 4.93 GB
#     - Average Monthly Bill: $84.89
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C839, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C998 that aligns with their usage behavior.
#
# Generating offer for Customer: C999
# Similar Customer: C538
# Customer Data: {'Customer_ID': 'C999', 'Monthly_Calls': 366, 'Monthly_SMS': 25, 'Data_Usage_GB': 6.371923264884821, 'Subscription_Type': 1, 'Average_Bill': 60.22768327843595, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C999:
#     A telecom customer C999 has the following usage pattern:
#     - Monthly Calls: 366 mins
#     - Monthly SMS: 25
#     - Data Usage: 6.37 GB
#     - Average Monthly Bill: $60.23
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C538, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C999 that aligns with their usage behavior.
#
# Generating offer for Customer: C1000
# Similar Customer: C332
# Customer Data: {'Customer_ID': 'C1000', 'Monthly_Calls': 278, 'Monthly_SMS': 24, 'Data_Usage_GB': 11.60427053627573, 'Subscription_Type': 1, 'Average_Bill': 79.22389387287363, 'Recommended_Offer': 'LLM Error: Got unknown type \n'}
# Prompt for C1000:
#     A telecom customer C1000 has the following usage pattern:
#     - Monthly Calls: 278 mins
#     - Monthly SMS: 24
#     - Data Usage: 11.6 GB
#     - Average Monthly Bill: $79.22
#     - Subscription Type: Postpaid
#
#     Their most similar customer is C332, who has a similar usage profile.
#
#     Based on this, suggest a personalized offer for customer C1000 that aligns with their usage behavior.

# %%
df.head()
# Out:
#   Customer_ID  Monthly_Calls  Monthly_SMS  Data_Usage_GB  Subscription_Type  \
# 0          C1            443           38      16.092193                  0
# 1          C2            546           27       4.297761                  0
# 2          C3            341           30       7.739410                  0
# 3          C4            424           25       5.754387                  0
# 4          C5            295           35       5.823838                  1
#
#    Average_Bill               Recommended_Offer
# 0     37.271282  LLM Error: Got unknown type \n
# 1     51.386492  LLM Error: Got unknown type \n
# 2     20.332755  LLM Error: Got unknown type \n
# 3     25.643831  LLM Error: Got unknown type \n
# 4     92.985287  LLM Error: Got unknown type \n
